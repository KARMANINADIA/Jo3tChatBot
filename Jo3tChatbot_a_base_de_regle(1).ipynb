# %% [markdown]
# Install Libraries

# %%
# !pip install nltk

# %% [markdown]
# Import Libraries

# %%
import nltk
from nltk.chat.util import Chat, reflections

# %% [markdown]
# design  GUI using the Python Tkinter module

# %% [markdown]
# reflections dictionary

# %%
reflections = {
    "أنا" : "إنتِ",
    "كنت" : "كنتِ",
    "أنا" : "إنتِ",
    "أنا" : "إنتِ",
    "أنا كنت" : "إنتِ كنت",
    "معايا" : "معاك",
    "لي" : "ليك",
    "إنتِ" : "أنا",
    "كنتي" : "كنت",
    "عندك" : "عندي",
    "باش تعمل" : "باش نعمل",
    "ليك" : "لي",
    "متاعك" : "متاعي",
    "متاعك" : "متاعي",
    "إنت" : "أنا",
    "أنا" : "إنت"
}

# %% [markdown]
# conversation **rules**

# %%
pairs = [

    [
        r"اسمي (.*)",
        ["مرحبا %1، كفاش الاحوال اليوم؟",]
    ],
    [
        r"سلام|هاي|مرحبا",
        ["مرحبا!", "أهلا بيك!",]
    ],
    [
        r"شنوة اسمك؟",
        ["أنا Jo3tchat، ندبر معاك في recette فطورك!",]
    ],


    [
        r"(.*)(سلام|مساء النور|أهلا)",
        ["مساء النور! شنوّة تحب نعاونك في حاجة؟"]
    ],
    [
        r"(.*)(جيعان|نحب نطيب حاجة خفيفة)(.*)",
        ["تنجم تعمل عشا خفيف كيف سلاطة ولا شربة."]
    ],
    [
        r"(.*)(شربة|دشيشء)",
        ["نعطيك وصفة شربة لسان عصفور."]
    ],
    [
        r"(.*)(سندويتش|كاسكروت|صندويتش)",
        ["نجم نوريك كيفاش تعمل سندويتش ب شوية سكالوپ وجبن."]
    ],
    [
        r"(.*)(شكرا|مرسي|بارك الله فيك)",
        ["الصحة و بالشفاء! كان تحب حاجة أخرى، راني هنا."]
    ],
    [
        r"(.*)(خرج|باي|إنهاء|)",
        ["بالسلامة! تلهى  بروحك."]
    ],

    [
        r"(.*)(شنوّة تحب|شنية تحب)(.*)(ماكلة|ناكل)(.*)",
        ["شنوة تحب نعاونك باش تختار الماكلة؟",]
    ],
    [
        r"(.*)(نحب|حاب)(.*)(شيء|حاجة)(.*)(خفيف|خفيفة)",
        ["تنجم تعمل حاجة خفيفة كيف سلطة ولا شربة.",]
    ],
    [
        r"(.*)(لا|مش لازم|ما نحبش)",
        ["إذاً نجم ننصحك بحاجة أخرى، شنوّة رأيك؟",]
    ],
    [
        r"(.*)(نحب|حاب)(.*)(ماكلة|مأكولات)(.*)(سريعة)",
        ["المأكولات السريعة تنجم تكون كفتاجي ولا ساندويتش تونسي.",]
    ],
    [
        r"(.*)(شكرا|مرسي|يعطيك الصحة)",
        ["العفو! إذا حبيت حاجة أخرى، راني هنا."],
    ],

    [
        r"تحب تختار اكلة اليوم؟",
        ["تحب نعاونك باش تختار حاجة تاكلها اليوم؟"]
    ],
    [
        r" منعرش؟",
        ["عندي برشا حاجات نجم نقترحها عليك، حسب شنوّة يعجبك."]
    ],
    [
        r" هات اش عندك ؟",
        ["تحب تاكل في الدار و الا البراس"]
    ],
    [
        r"البرا",
        ["ما نجم نعاونك كان في الدار والا في نصيحة ليك"]
    ],
    [
        r"باهي قولي شنوة باش نطيب",
        ["تحب تحضر حاجة حلوة ولا مالح"]
    ],
    [
        r"نبدأ بالملاح",
        ["تحبها بالخبز ولا بالمغرفة؟"]
    ],
    [
        r"نحبها بالمغرفة ومشخشخة بجبونات",
        ["بيه، تنجم تعملها بجبنات وتحط شوية زيت زيتونة باش تجي بنينة!"]
    ],
    [
        r"شنوّة رايك في مقرونة فل باللحم والموزاريلا",
        ["فكرة حلوة برشة! وفوقها قرن فلفل مقلي ر."]
    ],
    [
        r"آيا باهي كي عجبتك الفكرة، تستحق حاجة أخرى؟",
        ["إي، لازمنا نحلّيو."]
    ],
    [
        r"أنا فهمتك على شنوّة تلوج، شنوّة رايك في كاس بوزة بفريوة مرشوق وفيها صبع زريقة؟",
        ["   بالحق! هذي بالضبط الوصفة اللي تجي قد قد! اطلع بالروسات"]
    ],
    [
        r" هذي اللي بيك تدلل",
        ["زايد معاك"]
    ]
      ]
    [
        r"اسمي (.*)",
        ["مرحبا %1، كفاش الاحوال اليوم؟"]
    ],
    [
        r"سلام|مساء النور|أهلا|عسلامة",
        ["راني حرّت وحار دليلي؟"]
    ],
    [
        r"هاك الّي بك.. اشكيلي وقولي فاش تخمم",
        ["مانيش عارفة شنو نطيّب ليوم؟"]
    ],
    [
        r"تحب للفطور ولا للعشاء؟",
        ["للاثنين.. وحلو ومالح زادة.. عندي ضياف"]
    ],
    [
        r"شنو عندك في الدّار قضيّة؟",
        ["فمّا الخيرات السبعة.. غير حلهالي"]
    ],
    [
        r"بالنسبة للفطور.. تنجم تعمل كسكسي بلحم العلّوش.. ومعاه كاس تاي بالبندق ومقروض ورقة بالفور... وللعشاء.. حضّر حاجة خفيفة.. سلايط وشربة خضرة بالدجاج.. والحلو اعمل سلاطة غلّة",
        ["هاك طلعت معلّم.. اما الضيوف ميحبوش التاي بالبندق.. عندكش اقتراح آخر؟ وعلاش معاش نجم نحكي معاك بعد ه ميساج الخامس؟"]
    ],
    [
        r"اعمللهم قهاوي عربي.. ادفيو بيها قلبهم في ه البرد.. موش خير ؟؟",
        ["خاتر.. ما نجم نحكي مع حد ما نعرفوش.. كان 5 رسائل فقط... وحتى كان تسكر وتعاود تحل.. نبقى ديما إلا اذا تحل كونت ونوليو صحاب"]
    ],
    [
        r"شنو عندك في الدّار قضيّة؟",
        ["فمّا الخيرات السبعة.. غير حلهالي"]
    ],
    [
        r"سلام|هاي|مرحبا",
        ["مرحبا!", "أهلا بيك!"]
    ],
    [
        r"شنوة اسمك؟",
        ["أنا تشات جبيتي، تحب ندبر معاك في رسات للفطور!"]
    ],
    [
        r"(.*)(سلام|مساء النور|أهلا)",
        ["مساء النور! شنوّة تحب نعاونك في حاجة؟"]
    ],
    [
        r"(.*)(جيعان|نحب نطيب حاجة خفيفة| عندكش دبارة دبر عليا؟)(.*)",
        ["تنجم تعمل عشا خفيف كيف سلاطة ولا شربة."]
    ],
    [
        r"(.*)(قلي كيفاش| نحب سلاطة قلي كيفاش | نحب دشيش | نحب شربة)",
        ["تنجم تعمل شربة عربي: سخن شوية زيت، زيد فيه بصلة وثوم، بعد حط شوية حمص وعود قرفة وزيدهم بالماء. خليه يطيب وبعد ما تغلي، زيد شوية شعرية ولا دشيشة على كيفك. | الدشيش التونسي ساهل: سخن زيت مع بصل، زيد عليه ماء وحط دشيشة. خليه يطيب على نار هادية وحط شوية ملح وتابل وكروية. بالشفاء! | تنجم تعمل سلاطة خضرة: قص خس، طماطم، خيار، وزيد شوية زيت زيتونة وعصرة قارس."]
    ],
    [
        r"(.*)(تتجم توريني كيفاش نعمل سندويتش|كاسكروت|صندويتش)",
        ["خذ خبزة باڨيت، قصها من النّص وحط فيها شريحة جبن من الجهتين. في مقلة، سخّن شوية زيت زيتونة وطيّب السكالوپ بالملح والفلفل الأكحل حتى يولي لونو ذهبي. حطّ السكالوپ في الخبزة فوق الجبن، وزيد خس وطماطم (إذا تحب). سكّر الخبزة، وإذا تحبها مقرمشة، حطها شوية في المقلة سخونة باش يذوب الجبن. بالشفاء!"]
    ],
    [
        r"(.*)(نحب نطيب كسكسي، كيفاش نعمل)",
        ["بيه، بش نطيب كسكسي تونسي بنين، لازمك المكونات هاذي:\n\nحضّر المرق: في الكسكاس، سخّن شوية زيت، زيد بصل مفروم، ثوم، وزيد الحم أو الدجاج. الي عندك، حط شوية ملح، فلفل أكحل، تابل، كروية، وفلفل أحمر، وفوّحهم مليح. بعد زيد الحمّص وخضر كيما القرع، بطاطا، وفلفل أخضر. بعد ما يشوّحو شوية، غطيهم بالماء وخليهم يطيبوا.\n\nحضّر الكسكسي: في القصعة، بلّل الكسكسي بشوية ماء وملح وزيت زيتونة، وخليه يتفور فوق المرق في الكسكاس. كلّ مرة حل الكسكاس وقلّب الكسكسي بشوية ماء حتى يجي مفور مليح.\n\nركّب الطبق: بعد ما يطيب المرق والكسكسي، حطّ الكسكسي في صحن كبير، وسقيه بالمرق وحط الخضر والحم فوقه.\n\nبالشفاء!"]
    ],
    [
        r"(.*)(شكرا|مرسي|بارك الله فيك)",
        ["الصحة و بالشفاء! كان تحب حاجة أخرى، راني هنا."]
    ],
    [
        r"(.*)(بالسلامة|باي|باي باي)",
        ["بالسلامة! تلهى بروحك."]
    ],
    [
        r"(.*)(شنوّة تحب|شنية تحب)(.*)(ماكلة|ناكل)(.*)",
        ["شنوة تحب نعاونك باش تختار الماكلة؟"]
    ],
    [
        r"(.*)(نحب|حاب)(.*)(شيء|حاجة)(.*)(خفيف|خفيفة)",
        ["تنجم تعمل حاجة خفيفة كيف سلطة ولا شربة."]
    ],
    [
        r"(.*)(لا|مش لازم|ما نحبش)",
        ["إذاً نجم ننصحك بحاجة أخرى، شنوّة رأيك؟"]
    ],
    [
        r"(.*)(نحب|حاب)(.*)(ماكلة|مأكولات)(.*)(سريعة)",
        ["المأكولات السريعة تنجم تكون كفتاجي ولا ساندويتش تونسي."]
    ],
    [
        r"(.*)(شكرا|مرسي|يعطيك الصحة)",
        ["العفو! إذا حبيت حاجة أخرى، راني هنا."]
    ],
    [
        r"تحب تختار اكلة اليوم؟",
        ["تحب نعاونك باش تختار حاجة تاكلها اليوم؟"]
    ],
    [
        r"منعرش؟",
        ["عندي برشا حاجات نجم نقترحها عليك، حسب شنوّة يعجبك."]
    ],
    [
        r"هات اش عندك؟",
        ["تحب تاكل في الدار ولا البرا؟"]
    ],
    [
        r"البرا",
        ["ما نجم نعاونك كان في الدار والا في نصيحة ليك"]
    ],
    [
        r"باهي قولي شنوّة باش نطيب",
        ["تحب تحضر حاجة حلوة ولا مالح؟"]
    ],
    [
        r"نبدأ بالملاح",
        ["تحبها بالخبز ولا بالمغرفة؟"]
    ],
    [
        r"شنوّة رايك في مقرونة فل باللحم والموزاريلا",
        ["فكرة حلوة برشة! وفوقها قرن فلفل مقلي."]
    ],
    [
        r"آيا باهي كي عجبتك الفكرة، تستحق حاجة أخرى؟",
        ["إي، لازمنا نحلّيو."]
    ],
    [
        r"أنا فهمتك على شنوّة تلوج، شنوّة رايك في كاس بوزة بفريوة مرشوق وفيها صبع زريقة؟",
        ["بالحق! هذي بالضبط الوصفة اللي تجي قد قد! اطلع بالروسات."]
    ],
    [
        r"شوف معايا: 150غرام بوفريوة تحمصها وترحيها بالباهى لين اتقر زيتها في كسرونة تحط لتر حليب ونصف حكة نستلي ومغرفة كبيرة و نصف نشاء و مغرفتين سكر و اتحرك و بعد اتزيد البوفريوة المرحية و اتحرك وبعد اتطيبهم على نار هادية مع التحريك وبعد تصبهم في كيسان و اتزين بصبع زريقة في الوسط،. وبالشفا!",
        ["زايد معاك"]
    ]
]

# %% [markdown]
# ** Create the Jo3tChatbot Function**

# %%
def start_chat():
    print("مرحب! معاك جعت تشات بوت. Type 'quit' to exit.")
    chat = Chat(pairs, reflections)
    chat.converse()

# %% [markdown]
#  Run the **Jo3tChatbot**

# %%
start_chat()
# Out:
# مرحب! معاك جعت تشات بوت. Type 'quit' to exit.
# > ahla
# بالسلامة! تلهى  بروحك.
# > huh
# بالسلامة! تلهى  بروحك.
# > سلمة نحب ناكل حاجة حارة
# بالسلامة! تلهى  بروحك.
# > سلمة نحب ناكل حاجة حارة
# بالسلامة! تلهى  بروحك.
# > عسلامة نحب ناكل حاجة حارة
# مساء النور! شنوّة تحب نعاونك في حاجة؟
# > عسلامة نحب ناكل حاجة حارة
# مساء النور! شنوّة تحب نعاونك في حاجة؟

# %% [markdown]
# Testing the **Jo3tChatbot**

# %%
# !pip install nltk
